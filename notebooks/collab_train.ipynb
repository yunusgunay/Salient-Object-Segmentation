# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# %cd /content
# !rm -rf Salient-Object-Segmentation
# !git clone --branch feature/CNN_Unet_v2 https://github.com/yunusgunay/Salient-Object-Segmentation.git
# Out:
# /content
# Cloning into 'Salient-Object-Segmentation'...
# remote: Enumerating objects: 2188, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 2188 (delta 83), reused 138 (delta 49), pack-reused 2016 (from 2)
# Receiving objects: 100% (2188/2188), 67.78 MiB | 18.84 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# %cd /content/Salient-Object-Segmentation
# !ls
# Out:
# /content/Salient-Object-Segmentation
# data		       IMPROVEMENTS.md	notebooks  README.md	     src
# group_19_progress.pdf  LICENSE		outputs    requirements.txt

# %%
#%%capture
#!pip install -r requirements.txt

# %%
# CNN
# !python -m src.train_cnn
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train samples: 700
# Val samples: 150
# Test samples: 150
# Epoch [1/10] | Train Loss: 0.6069 | Val Loss: 0.5822 | Val IoU: 0.0000 | Val Dice: 0.0000 | Val Precision: 0.0000 | Val Recall: 0.0000 | Val F-measure: 0.0000
# Saved best model to outputs/checkpoints/cnn_best_model.pth
# Epoch [2/10] | Train Loss: 0.5515 | Val Loss: 0.5669 | Val IoU: 0.0000 | Val Dice: 0.0000 | Val Precision: 0.0000 | Val Recall: 0.0000 | Val F-measure: 0.0000
# Epoch [3/10] | Train Loss: 0.5353 | Val Loss: 0.5556 | Val IoU: 0.0000 | Val Dice: 0.0000 | Val Precision: 0.0000 | Val Recall: 0.0000 | Val F-measure: 0.0000
# Epoch [4/10] | Train Loss: 0.5261 | Val Loss: 0.5490 | Val IoU: 0.0000 | Val Dice: 0.0000 | Val Precision: 0.0000 | Val Recall: 0.0000 | Val F-measure: 0.0000
# Epoch [5/10] | Train Loss: 0.5238 | Val Loss: 0.5450 | Val IoU: 0.0000 | Val Dice: 0.0000 | Val Precision: 0.0000 | Val Recall: 0.0000 | Val F-measure: 0.0000
# ...

# %%
from google.colab import files
files.download("outputs/predictions/cnn_pr_curve.png")

# %%
files.download("outputs/predictions/cnn_loss_curve.png")

# %%
files.download("outputs/checkpoints/cnn_best_model.pth")

# %%
# U-NET
# !python -m src.train_unet
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train samples: 700
# Val samples: 150
# Test samples: 150
# Epoch [1/10] | Train Loss: 0.5200 | Val Loss: 0.4639 | Val IoU: 0.3154 | Val Dice: 0.4361 | Val Precision: 0.5710 | Val Recall: 0.4504 | Val F-measure: 0.4361
# Saved best model to outputs/checkpoints/unet_best_model.pth
# Epoch [2/10] | Train Loss: 0.4215 | Val Loss: 0.4257 | Val IoU: 0.4224 | Val Dice: 0.5700 | Val Precision: 0.6194 | Val Recall: 0.6513 | Val F-measure: 0.5700
# Saved best model to outputs/checkpoints/unet_best_model.pth
# Epoch [3/10] | Train Loss: 0.4013 | Val Loss: 0.4015 | Val IoU: 0.4011 | Val Dice: 0.5438 | Val Precision: 0.6586 | Val Recall: 0.5567 | Val F-measure: 0.5438
# Epoch [4/10] | Train Loss: 0.3927 | Val Loss: 0.5026 | Val IoU: 0.4213 | Val Dice: 0.5731 | Val Precision: 0.4896 | Val Recall: 0.8260 | Val F-measure: 0.5731
# Saved best model to outputs/checkpoints/unet_best_model.pth
# ...

# %%
files.download("outputs/predictions/unet_pr_curve.png")

# %%
files.download("outputs/predictions/unet_loss_curve.png")

# %%
files.download("outputs/checkpoints/unet_best_model.pth")

# %%
# DINO
# !python -m src.train_dino
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train samples: 700
# Val samples: 150
# Test samples: 150
# ...
# model.safetensors: 100% 86.7M/86.7M [00:03<00:00, 25.3MB/s]
# Epoch [1/10] | Train Loss: 0.4735 | Val Loss: 0.3323 | Val IoU: 0.7639 | Val Dice: 0.8608 | Val Precision: 0.8547 | Val Recall: 0.8861 | Val F-measure: 0.8608
# Saved best model to outputs/checkpoints/dino_best_model.pth
# Epoch [2/10] | Train Loss: 0.3024 | Val Loss: 0.2623 | Val IoU: 0.7790 | Val Dice: 0.8697 | Val Precision: 0.8418 | Val Recall: 0.9195 | Val F-measure: 0.8697
# Saved best model to outputs/checkpoints/dino_best_model.pth
# Epoch [3/10] | Train Loss: 0.2243 | Val Loss: 0.2157 | Val IoU: 0.7920 | Val Dice: 0.8778 | Val Precision: 0.8542 | Val Recall: 0.9203 | Val F-measure: 0.8778
# Saved best model to outputs/checkpoints/dino_best_model.pth
# Epoch [4/10] | Train Loss: 0.1739 | Val Loss: 0.1878 | Val IoU: 0.7966 | Val Dice: 0.8804 | Val Precision: 0.8802 | Val Recall: 0.8970 | Val F-measure: 0.8804
# ...

# %%
files.download("outputs/predictions/dino_pr_curve.png")

# %%
files.download("outputs/predictions/dino_loss_curve.png")

# %%
files.download("outputs/checkpoints/dino_best_model.pth")

# %%
# CLIP
# !python -m src.train_clip
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train samples: 700
# Val samples: 150
# Test samples: 150
# ...
# pytorch_model.bin: 100% 599M/599M [00:03<00:00, 165MB/s]
# Epoch [1/10] | Train Loss: 0.5012 | Val Loss: 0.4085 | Val IoU: 0.7086 | Val Dice: 0.8190 | Val Precision: 0.7813 | Val Recall: 0.8967 | Val F-measure: 0.8190
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [2/10] | Train Loss: 0.3529 | Val Loss: 0.2994 | Val IoU: 0.7338 | Val Dice: 0.8368 | Val Precision: 0.8405 | Val Recall: 0.8678 | Val F-measure: 0.8368
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [3/10] | Train Loss: 0.2635 | Val Loss: 0.2598 | Val IoU: 0.7370 | Val Dice: 0.8376 | Val Precision: 0.8533 | Val Recall: 0.8609 | Val F-measure: 0.8376
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [4/10] | Train Loss: 0.2058 | Val Loss: 0.2225 | Val IoU: 0.7399 | Val Dice: 0.8419 | Val Precision: 0.8671 | Val Recall: 0.8472 | Val F-measure: 0.8419
# ...

# %%
files.download("outputs/predictions/clip_pr_curve.png")

# %%
files.download("outputs/predictions/clip_loss_curve.png")

# %%
files.download("outputs/checkpoints/clip_best_model.pth")

# %% [markdown]
# # Improved Models (v2)
# CNN with skip connections + BatchNorm + BCEDice loss + augmentation (50 epochs)
# U-Net with Dropout bottleneck + BCEDice loss + augmentation (50 epochs)
# Outputs saved to `outputs_v2/` for direct comparison with v1.

# %%
# CNN Improved (v2) — ~50 epochs, expect significant increase from F=0.1037
# !python -m src.train_cnn_v2

# %%
from google.colab import files
files.download("outputs_v2/predictions/cnn_improved_pr_curve.png")
files.download("outputs_v2/predictions/cnn_improved_loss_curve.png")
files.download("outputs_v2/predictions/cnn_improved_results.txt")
files.download("outputs_v2/checkpoints/cnn_improved_best_model.pth")

# %%
# U-Net Improved (v2) — 50 epochs, expect precision improvement from 0.5013
# !python -m src.train_unet_v2
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train: 700 | Val: 150 | Test: 150
# Epoch [1/150] | LR: 1.00e-03 | Train Loss: 0.5838 | Val Loss: 0.5822 | Val Dice: 0.4965 | Val Prec: 0.4496 | Val Rec: 0.7409
#   -> Saved best model (Val Dice: 0.4965)
# Epoch [2/150] | LR: 1.00e-03 | Train Loss: 0.4761 | Val Loss: 0.5009 | Val Dice: 0.4811 | Val Prec: 0.6840 | Val Rec: 0.4419
# Epoch [3/150] | LR: 1.00e-03 | Train Loss: 0.4582 | Val Loss: 0.6254 | Val Dice: 0.4306 | Val Prec: 0.5634 | Val Rec: 0.4454
# Epoch [4/150] | LR: 1.00e-03 | Train Loss: 0.4526 | Val Loss: 0.6808 | Val Dice: 0.5732 | Val Prec: 0.4747 | Val Rec: 0.8839
#   -> Saved best model (Val Dice: 0.5732)
# Epoch [5/150] | LR: 1.00e-03 | Train Loss: 0.4516 | Val Loss: 0.6125 | Val Dice: 0.5663 | Val Prec: 0.5122 | Val Rec: 0.8016
# Epoch [6/150] | LR: 1.00e-03 | Train Loss: 0.4458 | Val Loss: 0.4886 | Val Dice: 0.5217 | Val Prec: 0.6802 | Val Rec: 0.5168
# ...

# %%
files.download("outputs_v2/predictions/unet_improved_pr_curve.png")
files.download("outputs_v2/predictions/unet_improved_loss_curve.png")
files.download("outputs_v2/predictions/unet_improved_results.txt")
files.download("outputs_v2/checkpoints/unet_improved_best_model.pth")

# %%
# !python -m src.train_clip_v2

# %%
from google.colab import files
files.download("outputs_v2/predictions/clip_v2_pr_curve.png")
files.download("outputs_v2/predictions/clip_v2_loss_curve.png")
files.download("outputs_v2/predictions/clip_v2_results.txt")
files.download("outputs_v2/checkpoints/clip_v2_best_model.pth")

# %%
# !python -m src.train_dino_v2

# %%
from google.colab import files
files.download("outputs_v2/predictions/dino_v2_pr_curve.png")
files.download("outputs_v2/predictions/dino_v2_loss_curve.png")
files.download("outputs_v2/predictions/dino_v2_results.txt")
files.download("outputs_v2/checkpoints/dino_v2_best_model.pth")

# %%
# !python -m src.eval_late_fusion

# %%
from google.colab import files
files.download("outputs_v2/predictions/late_fusion_pr_curve.png")
files.download("outputs_v2/predictions/late_fusion_results.png")
