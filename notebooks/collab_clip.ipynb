# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/yunusgunay/Salient-Object-Segmentation.git
# Out:
# Cloning into 'Salient-Object-Segmentation'...
# remote: Enumerating objects: 2104, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2104 (delta 34), reused 73 (delta 19), pack-reused 2016 (from 2)
# Receiving objects: 100% (2104/2104), 66.65 MiB | 30.69 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd /content/Salient-Object-Segmentation
# !ls
# Out:
# /content/Salient-Object-Segmentation
# data  LICENSE  notebooks  outputs  README.md  requirements.txt	src

# %%
# %%capture
# !pip install -r requirements.txt

# %%
# !python -m src.train_clip
# Out:
# Using device: cuda
# Matched pairs: 1000
# Train samples: 700
# Val samples: 150
# Test samples: 150
# ...
# pytorch_model.bin: 100% 599M/599M [00:03<00:00, 156MB/s]
# Epoch [1/10] | Train Loss: 0.5012 | Val Loss: 0.4085 | Val IoU: 0.7086 | Val Dice: 0.8190 | Val Precision: 0.7813 | Val Recall: 0.8967 | Val F-measure: 0.8190
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [2/10] | Train Loss: 0.3529 | Val Loss: 0.2994 | Val IoU: 0.7338 | Val Dice: 0.8368 | Val Precision: 0.8405 | Val Recall: 0.8678 | Val F-measure: 0.8368
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [3/10] | Train Loss: 0.2635 | Val Loss: 0.2598 | Val IoU: 0.7370 | Val Dice: 0.8376 | Val Precision: 0.8533 | Val Recall: 0.8609 | Val F-measure: 0.8376
# Saved best model to outputs/checkpoints/clip_best_model.pth
# Epoch [4/10] | Train Loss: 0.2058 | Val Loss: 0.2225 | Val IoU: 0.7399 | Val Dice: 0.8419 | Val Precision: 0.8671 | Val Recall: 0.8472 | Val F-measure: 0.8419
# ...

# %%
# !ls outputs/predictions
# Out:
# clip_pr_curve.png  cnn_pr_curve.png  dino_pr_curve.png	unet_pr_curve.png

# %%
from google.colab import files
files.download("outputs/predictions/clip_pr_curve.png")

# %%
files.download("outputs/predictions/clip_loss_curve.png")

# %%
files.download("outputs/checkpoints/clip_best_model.pth")
