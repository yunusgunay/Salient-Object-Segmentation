# %%
import sys
import matplotlib.pyplot as plt
from pathlib import Path

from PIL import Image
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
images_dir = Path("../data/images")
masks_dir = Path("../data/ground_truth_mask")

image_paths = sorted(list(images_dir.iterdir()))
mask_paths = sorted(list(masks_dir.iterdir()))

print("Images:", len(image_paths))
print("Masks:", len(mask_paths))
# Out:
# Images: 1000
# Masks: 1000

# %%
for i in range(3):
    img = Image.open(image_paths[i]).convert("RGB")
    mask = Image.open(mask_paths[i]).convert("L")

    plt.figure(figsize=(8,4))

    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.title("Image")
    plt.axis("off")

    plt.subplot(1,2,2)
    plt.imshow(mask, cmap="gray")
    plt.title("Mask")
    plt.axis("off")

    plt.show()

# %%
from src.dataset import get_image_mask_pairs, ECSSDDataset

pairs = get_image_mask_pairs("../data/images", "../data/ground_truth_mask")
dataset = ECSSDDataset(pairs)

image, mask = dataset[0]

print(image.shape)
print(mask.shape)
print(mask.min().item(), mask.max().item())
# Out:
# Matched pairs: 1000
# torch.Size([3, 256, 256])
# torch.Size([1, 256, 256])
# 0.0 1.0
